# %% [markdown]
# # Data Methods for Health Research : SYVM4

# %% [markdown]
# ### https://github.com/SYVM4

# %% [markdown]
# ## Assignment A
#
# The NHS has been challenged to make “efficiency savings” and you have been commissioned by an NHS executive to review, document and assess GP prescribing costs. Using data from the HSCIC GP Practice Prescribing dataset for your assigned city only, address the following queries using a combination of narrative, tables, figures and descriptive statistcs:

# %% [markdown]
# #### 1. Identify all GP practices and produce a table with the total number of prescriptions and their total actual cost(using the ACT COST column).

# %%
# Import Prelimminaries
import pandas as pd
import numpy as np


# %matplotlib inline
import random
import matplotlib.pyplot as plt

from math import floor

# %%
# Read in the practice data into a dataframe
url = 'https://s3.eu-west-2.amazonaws.com/dmhr-data/practices_Dec2015.csv'
cols2 = ['yearmonth', 'prac_code', 'practice', 'address1', 'address2',
         'city', 'region', 'postcode']
practice_df = pd.read_csv(url, header=None, names=cols2, index_col=False,
                          skiprows=1).rename(columns=lambda x: x.strip())
practice_df.head()
# Out:
#    yearmonth prac_code                                  practice  \
# 0     201512    A81002  QUEENS PARK MEDICAL CENTRE
# 1     201512    A81003  VICTORIA MEDICAL PRACTICE
# 2     201512    A81004  WOODLANDS ROAD SURGERY
# 3     201512    A81005  SPRINGWOOD SURGERY
# 4     201512    A81006  TENNANT STREET MEDICAL PRACTICE
#
#                     address1                   address2  \
# 0  QUEENS PARK MEDICAL CTR    FARRER STREET
# 1  THE HEALTH CENTRE          VICTORIA ROAD
# 2  6 WOODLANDS ROAD
# 3  SPRINGWOOD SURGERY         RECTORY LANE
# 4  TENNANT ST MED PRACT       FARRER STREET
#
#                         city                     region  \
# 0  STOCKTON ON TEES           CLEVELAND
# 1  HARTLEPOOL                 CLEVELAND
# 2  MIDDLESBROUGH              CLEVELAND
# 3  GUISBOROUGH
# 4  STOCKTON ON TEES           CLEVELAND
#
#                     postcode
# 0  TS18 2AW
# 1  TS26 8DB
# 2  TS1 3BE
# 3  TS14 7DJ
# 4  TS18 2AT

# %%
# Read in the prescribing data into a dataframe
url = 'https://s3.eu-west-2.amazonaws.com/dmhr-data/prescribing_Dec2015.csv'
cols2 = ['sha', 'pct', 'prac_code', 'bnf_code', 'bnf_name', 'items',
         'nic', 'act_cost', 'quantity', 'period']
prescribing_df = pd.read_csv(url, header=None, names=cols2, index_col=False,
                             skiprows=1).rename(columns=lambda x: x.strip())
prescribing_df.head()
# Out:
#    sha  pct prac_code         bnf_code  \
# 0  Q44  RJN    Y05218  0501013K0AAAJAJ
# 1  Q44  RJN    Y05218  0501130R0AAAAAA
# 2  Q44  RTV    Y04937  0401020K0AAAHAH
# 3  Q44  RTV    Y04937  0401020P0AAABAB
# 4  Q44  RTV    Y04937  0402010ABAAABAB
#
#                                    bnf_name  items    nic  act_cost  quantity  \
# 0  Co-Amoxiclav_Tab 500mg/125mg                  1   3.59      3.33        21
# 1  Nitrofurantoin_Cap 50mg                       1  14.39     13.42        28
# 2  Diazepam_Tab 2mg                              1   0.51      0.58        14
# 3  Lorazepam_Tab 1mg                             1   2.65      2.46        28
# 4  Quetiapine_Tab 25mg                           2   2.01      2.08        84
#
#    period
# 0  201512
# 1  201512
# 2  201512
# 3  201512
# 4  201512

# %%
# Identify all the Sheffield practices in the practice dataset and 
# create a seperate dataframe
# Sheffield practice can be identified by using the city column 
shef_prac1 = practice_df.loc[practice_df['city'].str.contains('sheffield',
                                                              case=False)]

# Merge the sheffield practices dataframe and the prescribing dataframe  
# create a dataframe with all prescribing data in sheffield
sheff_prac = pd.merge(shef_prac1, prescribing_df, on='prac_code')

# %%
# use iloc function to output columns of interest 
sheff_prac1 = sheff_prac.iloc[:, [1,12,14,15]]


# group the dataframe by practice code
# sum the entire dataframe to observe total actual cost of each practice code
sheff_prac2 = sheff_prac1.groupby('prac_code').sum()

# %%
# Sheffield GPs with total number of prescriptions(quanitity) and ACT cost 

# create a merged dataframe with sheffield practice code and actual costs
# reset index 
all_prac = practice_df.set_index('prac_code')

# Merge the dataframes
shef_pres = pd.merge(all_prac, sheff_prac2, right_index=True, left_index=True)

shef_pres1 = shef_pres.iloc[:, [1,4,7,8,9]]
shef_pres1.head()
# Out:
#                                            practice  \
# prac_code
# C81002     MOSS VALLEY MEDICAL PRACTICE
# C81070     OAKHILL MEDICAL PRACTICE
# C81095     DR HR MCMURRAY'S PRACTICE
# C85004     PENISTONE GROUP PMS PRACTICE
# C87004     KIVETON PARK MEDICAL PRACTICE
#
#                                 city  items   act_cost  quantity
# prac_code
# C81002     SHEFFIELD                  21270  122603.75   1594078
# C81070     SHEFFIELD                  11805   82388.35    906422
# C81095     NR.SHEFFIELD                6762   48849.79    464217
# C85004     PENISTONE  SHEFFIELD       40730  252318.29   2375126
# C87004     SHEFFIELD                  26213  193432.30   1382116

# %%
shef_pres1.describe()
# Out:
#               items       act_cost      quantity
# count    108.000000     108.000000  1.080000e+02
# mean   11894.555556   87244.300278  9.039563e+05
# std     9698.723912   65055.526014  6.878234e+05
# min        3.000000       6.290000  1.330000e+02
# 25%     4833.000000   34078.577500  3.274660e+05
# 50%    10693.500000   82180.380000  8.991220e+05
# 75%    16906.750000  125747.975000  1.326288e+06
# max    47086.000000  267142.150000  3.162149e+06

# %% [markdown]
# #### 2. Find the top ten most/least frequently prescribed medications across all practices.

# %%
# Group by drug name
shef_pres_total = sheff_prac.groupby('bnf_name')['items', 'act_cost'].sum()
shef_pres_total.head()
# Out:
#                                           items  act_cost
# bnf_name
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa      1      0.51
# 3m Health Care_Cavilon Durable Barrier C    365   2949.57
# 3m Health Care_Cavilon No Sting 1ml Barr     14    254.42
# 3m Health Care_Cavilon No Sting 3ml Barr      8    200.55
# 3m Health Care_Cavilon No Sting Barrier     320   8262.94

# %%
#Top 10
shef_most = shef_pres_total.sort_values('items', axis=0, ascending = False).head(10)
shef_most
# Out:
#                                           items  act_cost
# bnf_name
# Omeprazole_Cap E/C 20mg                   29820  40265.54
# Paracet_Tab 500mg                         26927  90880.27
# Aspirin Disper_Tab 75mg                   26089  19920.15
# Simvastatin_Tab 40mg                      23191  24715.29
# Lansoprazole_Cap 30mg (E/C Gran)          20854  30966.07
# Amlodipine_Tab 5mg                        19637  18061.33
# Bendroflumethiazide_Tab 2.5mg             17673  15812.97
# Metformin HCl_Tab 500mg                   16502  62541.76
# Simvastatin_Tab 20mg                      15836  14217.11
# Atorvastatin_Tab 20mg                     13637  19469.93

# %%
# Last 10
shef_last = shef_pres_total.sort_values('items', axis=0, ascending = True).head(10)
shef_last
# Out:
#                                           items  act_cost
# bnf_name
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa      1      0.51
# Lofric Primo Nelaton Tiemann Non-PVC 10-      1    254.09
# Longtec_Tab 15mg M/R                          1     24.27
# Loperamide HCl_Oral Soln 25mg/5ml             1    156.33
# Lophlex_Pdr Sach 27.8g (Unflav)               1    267.98
# Lopresor Sr_Tab 200mg                         1      9.06
# Loprofin_L/P Bread Roll P/Bke                 1      7.78
# Loprofin_L/P Bread Roll Wte P/Bke             1     10.28
# Loprofin_L/P Cake Mix (2 Flav)                1     16.53
# Loprofin_L/P Cracker                          1      3.36

# %% [markdown]
# #### 2a. What is their total actual cost?

# %%
# The total actual cost of Top10 and Last 10
Top10_sum = shef_most['act_cost'].sum()
Last10_sum = shef_last['act_cost'].sum()
Overall_sum = shef_pres_total['act_cost'].sum()


print (Top10_sum) #Total Actual Cost of Top 10 most prescribed drugs
print (Last10_sum)#Total Actual cost of least 10 prescribed drugs
print (Overall_sum)#Total Actual cost of all GP practices
# Out:
# 336850.42
# 750.19
# 9422384.43

# %% [markdown]
# #### 2b. How does that compare to the overall actual costs of each practice and of the entire city?

# %%
# compare Top 10 and Last 10 with overall sum of entire city (Calculate percentage)
Top10_compare = Top10_sum / Overall_sum * 100
print (Top10_compare)

Last10_compare = Last10_sum / Overall_sum * 100
print (Last10_compare)
# Out:
# 3.5750018745520444
# 0.007961785104112972

# %% [markdown]
# #### 3. Find the top ten most expencive medications and calculate their total actual cost.

# %%
# Group by drug name
shef_pres_total1 = shef_pres_total.groupby('bnf_name')['items', 'act_cost'].sum()
shef_pres_total1.head()
# Out:
#                                           items  act_cost
# bnf_name
# 365 Non Adherent 10cm x 10cm Pfa Plas Fa      1      0.51
# 3m Health Care_Cavilon Durable Barrier C    365   2949.57
# 3m Health Care_Cavilon No Sting 1ml Barr     14    254.42
# 3m Health Care_Cavilon No Sting 3ml Barr      8    200.55
# 3m Health Care_Cavilon No Sting Barrier     320   8262.94

# %%
# Sort by Most expsensive
shef_expensive = shef_pres_total.sort_values('act_cost', axis=0, ascending = False).head(10)
shef_expensive.head()
# Out:
#                                           items   act_cost
# bnf_name
# Tiotropium_Pdr For Inh Cap 18mcg           5215  175579.16
# Rivaroxaban_Tab 20mg                       3083  151475.80
# Nefopam HCl_Tab 30mg                       2729   95526.07
# Paracet_Tab 500mg                         26927   90880.27
# Seretide 500_Accuhaler 500mcg/50mcg(60D)   2113   87239.91

# %%
# Total Actual cost of Top 10 most expensive
Top10_expensive = shef_expensive['act_cost'].sum()
print(Top10_expensive)
# Out:
# 964520.5900000001

# %% [markdown]
# #### 4. How does prescribing (frequency and costs) in your city compare when using prescribing data from Cambridge as a reference?

# %%
# Cambridge practices

practice_df.loc[practice_df['city'].str.contains('cambridge', case=False)]
camb_prac = practice_df.loc[practice_df['city'].str.contains('cambridge', case=False)]
camb_prac.head()
# Out:
#       yearmonth prac_code                                  practice  \
# 1534     201512    D81001  LENSFIELD MEDICAL PRACTICE
# 1535     201512    D81002  HUNTINGDON ROAD SURGERY
# 1536     201512    D81003  YORK STREET MEDICAL PRACTICE
# 1538     201512    D81005  NEWNHAM WALK SURGERY
# 1541     201512    D81009  SHELFORD MEDICAL PRACTICE
#
#                        address1                   address2  \
# 1534  LENSFIELD MEDICAL PRAC.    48 LENSFIELD ROAD
# 1535  HUNTINGDON ROAD SURGERY    1 HUNTINGDON ROAD
# 1536  YORK STREET MED PRACT.     146-148 YORK STREET
# 1538  NEWNHAM WALK SURGERY       WORDSWORTH GROVE
# 1541  SHELFORD MEDICAL PRACTICE  ASHEN GREEN GRT SHELFORD
#
#                            city                     region  \
# 1534  CAMBRIDGE                  CAMBRIDGESHIRE
# 1535  CAMBRIDGE
# 1536  CAMBRIDGE                  CAMRIDGESHIRE
# 1538  CAMBRIDGE                  CAMBRIDGESHIRE
# 1541  CAMBRIDGE
#
#                        postcode
# 1534  CB2 1EH
# 1535  CB3 0DB
# 1536  CB1 2PY
# 1538  CB3 9HS
# 1541  CB22 5FY

# %%
# Cambridge Prescriptions
camb_pres= prescribing_df.loc[prescribing_df['prac_code'].str.contains('D8', case=False)]
camb_pres.head(5)
# Out:
#          sha  pct prac_code         bnf_code  \
# 4409460  Q56  RY3    D82643  0102000N0AAAAAA
# 4409461  Q56  RY3    D82643  0102000P0AAABAB
# 4409462  Q56  RY3    D82643  0103010T0AAAAAA
# 4409463  Q56  RY3    D82643  0103050L0AAAAAA
# 4409464  Q56  RY3    D82643  0106020B0AAAAAA
#
#                                          bnf_name  items     nic  act_cost  \
# 4409460  Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp        1    2.92      2.71
# 4409461  Mebeverine HCl_Tab 135mg                      1    5.48      5.18
# 4409462  Ranitidine HCl_Tab 150mg                      1    1.54      1.44
# 4409463  Lansoprazole_Cap 30mg (E/C Gran)              1    1.50      1.40
# 4409464  Co-Danthramer_Susp 25mg/200mg/5ml S/F         1  142.54    131.81
#
#          quantity  period
# 4409460        10  201512
# 4409461        42  201512
# 4409462        60  201512
# 4409463        28  201512
# 4409464       300  201512

# %%
#camb_pres1 = camb_pres.groupby("prac_code").sum()

# %%
# group by drugname
camb_pres_total = camb_pres.groupby('bnf_name')['items', 'act_cost'].sum()
camb_pres_total.head()
# Out:
#                                           items  act_cost
# bnf_name
# 365 Transpt Island 5cm x 7.2cm VP Adh Fi      1      0.47
# 3M Kind Removal 2.5cm x 5m Surg Adh Tape      6     33.13
# 3M Kind Removal 5cm x 5m Surg Adh Tape S      2     35.95
# 3m Health Care_Cavilon Durable Barrier C   5097  38982.35
# 3m Health Care_Cavilon No Sting 1ml Barr    231   3690.55

# %%
# Top 10 most prescriptions in Cambridge
camb_most = camb_pres_total.sort_values('items', axis=0, ascending = False).head(10)
camb_most
# Out:
#                                            items   act_cost
# bnf_name
# Omeprazole_Cap E/C 20mg                   114655  168006.99
# Aspirin Disper_Tab 75mg                    97422   81531.75
# Simvastatin_Tab 40mg                       86060   97936.98
# Paracet_Tab 500mg                          74943  269767.92
# Amlodipine_Tab 5mg                         66816   64453.52
# Bendroflumethiazide_Tab 2.5mg              59326   54252.67
# Simvastatin_Tab 20mg                       56634   56199.65
# Levothyrox Sod_Tab 100mcg                  55410  134236.79
# Lansoprazole_Cap 30mg (E/C Gran)           55036   85147.86
# Salbutamol_Inha 100mcg (200 D) CFF         54281   92336.63

# %%
# Top 10 least prescriptions in Cambridge
camb_last = camb_pres_total.sort_values('items', axis=0, ascending = True).head(10)
camb_last
# Out:
#                                           items  act_cost
# bnf_name
# 365 Transpt Island 5cm x 7.2cm VP Adh Fi      1      0.47
# Hydrocort But_Emuls 0.1%                      1      5.48
# Hydrocort_Liq Spec 5mg/5ml                    1    137.46
# Hydrofilm 10cm x 15cm VP Adh Film Dress       1      4.82
# Hydrogen Per_Soln 10vols/3%                   1      0.52
# Hydromorphone HCl_Cap 8mg M/R                 1    155.58
# Hydrosorb Comfort 7.5cm x 10cm Wound Dre      1     22.75
# Hygroton_Tab 50mg                             1      0.87
# Hypafix 5cm x 5m Surg Adh Tape Perm Non-      1      1.33
# Hypromellose_Eye Dps 0.5% P/F                 1     81.40

# %%
camb_pres_total1 = camb_pres.groupby('bnf_name')['nic', 'act_cost'].sum()
camb_pres_total1.head()
# Out:
#                                                nic  act_cost
# bnf_name
# 365 Transpt Island 5cm x 7.2cm VP Adh Fi      0.50      0.47
# 3M Kind Removal 2.5cm x 5m Surg Adh Tape     35.80     33.13
# 3M Kind Removal 5cm x 5m Surg Adh Tape S     38.88     35.95
# 3m Health Care_Cavilon Durable Barrier C  42094.24  38982.35
# 3m Health Care_Cavilon No Sting 1ml Barr   3990.00   3690.55

# %%
camb_expensive = camb_pres_total1.sort_values('act_cost', axis=0, ascending = False).head(10)
camb_expensive
# Out:
#                                                 nic   act_cost
# bnf_name
# Tiotropium_Pdr For Inh Cap 18mcg          475566.02  439867.26
# Fostair_Inh 100mcg/6mcg (120D) CFF        447687.08  414080.40
# Hydrocort_Tab 10mg                        359102.43  332133.06
# Paracet_Tab 500mg                         290043.78  269767.92
# Metformin HCl_Tab 500mg                   236196.79  219199.62
# Rivaroxaban_Tab 20mg                      228223.80  211118.56
# Symbicort_Turbohaler 200mcg/6mcg (120 D)  227468.00  210375.12
# Ins Lantus SoloStar_100u/ml 3ml Pf Pen    205242.40  189829.35
# Fluticasone/Salmeterol_Inh 250/25mcg120D  198603.72  183666.85
# Levothyrox Sod_Tab 25mcg                  194902.36  181082.98

# %%
# Total Actual cost of Top 10 most expensive
Top10_expensive_camb = camb_expensive['act_cost'].sum()
print(Top10_expensive_camb)
# Out:
# 2651121.1199999996

# %%
# Compare the frequency (Most expensive )

freq_comp = Top10_expensive_camb / Top10_expensive
freq_comp
# Out:
# 2.7486412913175853

# %% [markdown]
# #### 5.Using SQL, produce a table that provides the number of GP practices per city, ordered in descending order.

# %%
# !pip install pandasql
import pandas as pd
from pandasql import PandaSQL
pdsql = PandaSQL()
# Out:
# Requirement already satisfied: pandasql in /anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: sqlalchemy in /anaconda3/lib/python3.6/site-packages (from pandasql)
# Requirement already satisfied: numpy in /anaconda3/lib/python3.6/site-packages (from pandasql)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.6/site-packages (from pandasql)
# Requirement already satisfied: python-dateutil>=2 in /anaconda3/lib/python3.6/site-packages (from pandas->pandasql)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.6/site-packages (from pandas->pandasql)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.6/site-packages (from python-dateutil>=2->pandas->pandasql)

# %%
PRACTICES = print(pdsql("SELECT COUNT (prac_code), city\
                        FROM practice_df\
                        GROUP BY city\
                        ORDER BY COUNT (prac_code)\
                        DESC")
# Out:
#   File "<ipython-input-27-b5960a7e74b5>", line 1
#     PRACTICES = print(pdsql("SELECT COUNT (prac_code), city                        FROM practice_df                        GROUP BY city                        ORDER BY COUNT (prac_code)                        DESC")
#                                                                                                                                                                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # ASSIGNMENT B
#
# Using the entire dataset from the HSCIC GP Practice Prescribing data, address the following queries using a combination of narrative, tables, figures and descriptive statistics:

# %% [markdown]
# #### 1. Calculate the monthly total spending for each GP-practice.

# %%
# Monthly cost per each GP_practice code 

prescribing_all = prescribing_df.groupby('prac_code')['act_cost'].sum()
prescribing_all= prescribing_all.to_frame() 
prescribing_all.head()
# Out:
#             act_cost
# prac_code
# A81001      83220.57
# A81002     333514.67
# A81003      47977.16
# A81004     147494.85
# A81005     107669.51

# %%
# Monthly cost per each GP_practice names

prac_name = practice_df.groupby('prac_code')['practice'].sum()#structure the data into a table format for merging
prac_name= prac_name.to_frame()

prescribing_all = prescribing_df.groupby('prac_code')['act_cost'].sum()
prescribing_all= prescribing_all.to_frame() 

# merge along index to see total monthly spend per GP and GP_practice name and city
prac_name_pres = pd.merge(prac_name, prescribing_all, right_index=True, left_index=True)
prac_name_pres.head()
# Out:
#                                            practice   act_cost
# prac_code
# A81002     QUEENS PARK MEDICAL CENTRE                333514.67
# A81003     VICTORIA MEDICAL PRACTICE                  47977.16
# A81004     WOODLANDS ROAD SURGERY                    147494.85
# A81005     SPRINGWOOD SURGERY                        107669.51
# A81006     TENNANT STREET MEDICAL PRACTICE           197436.78

# %% [markdown]
# #### 2. Use the number of registered patients in each GP-practice to calculate the relative costs per patient.

# %%
# Reset index 
prac_name_pres.reset_index()

# import Patient demographic data
patient_url = 'https://digital.nhs.uk/media/28273/Numbers-of-Patients-Registered-at-a-GP-Practice-Jan-2016-GP-Practice-and-quinary-age-groups/Any/gp-reg-patients-prac-quin-age'
patient_demo = pd.read_csv(patient_url)
patient_demo.head()
# Out:
#   GP_PRACTICE_CODE  POSTCODE ONS_CCG_CODE CCG_CODE ONS_REGION_CODE  \
# 0           A81001  TS18 1HU    E38000075      00K       E39000027
# 1           A81002  TS18 2AW    E38000075      00K       E39000027
# 2           A81003  TS26 8DB    E38000075      00K       E39000027
# 3           A81004   TS1 3BE    E38000162      00M       E39000027
# 4           A81005  TS14 7DJ    E38000162      00M       E39000027
#
#   NHSE_REGION_CODE ONS_COMM_RGN_CODE NHSE_COMM_REGION_CODE  Total_All  \
# 0              Q74         E40000001                   Y54       4234
# 1              Q74         E40000001                   Y54      19691
# 2              Q74         E40000001                   Y54       3357
# 3              Q74         E40000001                   Y54       9151
# 4              Q74         E40000001                   Y54       7883
#
#    Total_Male     ...      Female_50-54  Female_55-59  Female_60-64  \
# 0        2061     ...               162           139           112
# 1        9706     ...               833           733           634
# 2        1779     ...               113           100            91
# 3        4774     ...               277           265           261
# 4        3826     ...               287           280           309
#
#    Female_65-69  Female_70-74  Female_75-79  Female_80-84  Female_85-89  \
# 0           134           104           120            94            59
# 1           636           483           445           362           231
# 2            94            49            44            38            18
# 3           228           205           210           165            91
# 4           368           253           183           144           102
#
#    Female_90-94  Female_95+
# 0            19           7
# 1           106          22
# 2            13           2
# 3            39          17
# 4            47          20
#
# [5 rows x 51 columns]

# %%
#Group the data by practice codes and show columns of interest, postcode and total number of patients 
patient_demo1 = patient_demo.groupby('GP_PRACTICE_CODE')['POSTCODE','Total_All'].sum()
pat_demo = patient_demo1.reset_index()

#Total Patients per GP practice
pat_demo.rename(columns={'GP_PRACTICE_CODE': 'prac_code', 'POSTCODE': 'postcode' }, inplace=True)
 

# Set index to prac code for merge
total_patient_demo = pat_demo.set_index('prac_code')

#merge the datasets
merged_df = pd.merge(prescribing_all, total_patient_demo, right_index=True, left_index = True)
merged_df.head()
# Out:
#             act_cost  Total_All
# prac_code
# A81001      83220.57       4234
# A81002     333514.67      19691
# A81003      47977.16       3357
# A81004     147494.85       9151
# A81005     107669.51       7883

# %%
#Relative cost per patient per GP practice
merged_df['relativecostperpatients'] =  merged_df['act_cost'] / merged_df['Total_All']

#rel_cost= (merged_df['relativecostperpatients'])
merged_df.head()
# Out:
#             act_cost  Total_All  relativecostperpatients
# prac_code
# A81001      83220.57       4234                19.655307
# A81002     333514.67      19691                16.937417
# A81003      47977.16       3357                14.291677
# A81004     147494.85       9151                16.117894
# A81005     107669.51       7883                13.658443

# %% [markdown]
# #### 3.Visualize the monthly total spending per registered patients for all GP-practices in a scatterplot, show a trend line, and visualize the data for your city within the national scatterplot

# %%
merged_df_reset = merged_df.reset_index()
merged_df_reset.head()
# Out:
#   prac_code   act_cost  Total_All  relativecostperpatients
# 0    A81001   83220.57       4234                19.655307
# 1    A81002  333514.67      19691                16.937417
# 2    A81003   47977.16       3357                14.291677
# 3    A81004  147494.85       9151                16.117894
# 4    A81005  107669.51       7883                13.658443

# %%
nationaldemo = merged_df_reset.groupby('prac_code')['Total_All','act_cost','relativecostperpatients'].sum()
nationaldemo.head()
# Out:
#            Total_All   act_cost  relativecostperpatients
# prac_code
# A81001          4234   83220.57                19.655307
# A81002         19691  333514.67                16.937417
# A81003          3357   47977.16                14.291677
# A81004          9151  147494.85                16.117894
# A81005          7883  107669.51                13.658443

# %%
#monthly Spending per GP practice in Sheffield 
sheffield_demo = merged_df_reset.loc[merged_df_reset['prac_code'].str.contains('C8', case=False)]
sheffield_demo.head()
# Out:
#     prac_code   act_cost  Total_All  relativecostperpatients
# 978    C81001  153830.15       9913                15.518022
# 979    C81002  122603.75       8386                14.620051
# 980    C81003  138351.42      10756                12.862720
# 981    C81004  141722.97      10738                13.198265
# 982    C81005  229131.76      17002                13.476753

# %%
# plot those data points
#fig, ax = plt.subplots()
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(8, 6))
ax=fig.add_subplot(111)
x= nationaldemo['act_cost']
y = nationaldemo['Total_All']

x1= sheffield_demo['act_cost']
y1= sheffield_demo['Total_All']

ax.scatter(x, y, color='royalblue')
ax.scatter(x1, y1, color='yellow')

fit = np.polyfit(x, y, deg=1)
ax.plot(x, fit[0] * x + fit[1], color='red')
ax.set_title('Monthly total spending per registered patients for all GP-practices compared to Sheffield')
ax.set_xlabel("Monthly Total Spend",fontsize=12)
ax.set_ylabel("Total Number of Registered Patients",fontsize=12)

max_x = (nationaldemo.act_cost.max())
max_y = (nationaldemo.Total_All.max())
ax.set_xlim(0, 700000)
ax.set_ylim(0, 40000)
# Out:
# (0, 40000)

# %% [markdown]
# ####  4.Visualize the relative costs per patient of all national GP-practices in a histogram.

# %%
#Delete outliers
rel_costs= nationaldemo.sort_values(by=['relativecostperpatients'], ascending=False)

relcosts= rel_costs[50:-4] #removing the outliers

x= relcosts.relativecostperpatients.values
plt.hist(x, bins=20,color='b')
plt.xlabel("Relative costs per patient")
plt.ylabel("Frequency")
plt.title("Relative costs per patient of all national GP-practices")
plt.show()

# %% [markdown]
# #### 5.Use descriptive statistics to show how your assigned city compares to the national level.

# %% [markdown]
# # Assignment C
# Using the entire dataset from the HSCIC GP Practice Prescribing data, address the following queries using a combination of narrative, tables, figures and descriptive statistcs:

# %% [markdown]
# #### 1. Identify for all GP-practices the relative costs per patient for all statin prescriptions (simvastatin, atorvastatin, rosuvastatin, pravastatin, fluvastatin) by using the dataset from December 2015.

# %%
# Filter out all the statin drugs.
statin_pres = prescribing_df.loc[prescribing_df['bnf_name'].str.contains('simvastatin|atorvastatin|rosuvastatin|pravastatin|fluvastatin',  case=False)]
statin_pres.head()
# Out:
#      sha  pct prac_code         bnf_code  \
# 102  Q44  RXA    Y00327  0212000B0AAACAC
# 103  Q44  RXA    Y00327  0212000Y0AAABAB
# 647  Q44  RY7    N85638  0212000B0AAABAB
# 648  Q44  RY7    N85638  0212000B0AAACAC
# 650  Q44  RY7    N85638  0212000X0AAAAAA
#
#                                      bnf_name  items   nic  act_cost  \
# 102  Atorvastatin_Tab 40mg                         2  1.67      1.67
# 103  Simvastatin_Tab 20mg                          1  0.10      0.20
# 647  Atorvastatin_Tab 20mg                         1  0.70      0.76
# 648  Atorvastatin_Tab 40mg                         1  0.06      0.17
# 650  Pravastatin Sod_Tab 10mg                      1  0.29      0.38
#
#      quantity  period
# 102        29  201512
# 103         3  201512
# 647        14  201512
# 648         1  201512
# 650         7  201512

# %%
# MergeDataframes to identify relative cost per patients for all statin costs

# Create new dataframe with statin data grouped prac_code as index 
statin = statin_pres.groupby('prac_code')['act_cost', 'nic', 'quantity'].sum()

# Create new dataframe with total patient data grouped prac_code as index 
patient_demo2 = patient_demo.groupby('GP_PRACTICE_CODE')['POSTCODE','Total_All'].sum()

# merge along the index
total_statin = pd.merge(statin, patient_demo2, right_index=True, left_index=True)

# Create function to calculate the relative Cost Per pateint Across all GP practices for Statin prescriptions

total_statin['relative cost per patient'] = total_statin['act_cost'] / total_statin['Total_All']
total_statin.head()
# Out:
#         act_cost      nic  quantity  Total_All  relative cost per patient
# A81001   1816.80  1956.63     18792       4234                   0.429098
# A81002   6513.51  6997.64     98340      19691                   0.330786
# A81003    868.39   925.06     17464       3357                   0.258680
# A81004   2134.60  2289.98     36302       9151                   0.233264
# A81005   1887.11  2019.19     35575       7883                   0.239390

# %% [markdown]
# #### 2.Identify for all GP-practice the associated Index of Multiple Deprivation (IMD) for each GP-Practice in your assigned city.

# %%
#import the data 
url = 'https://s3.eu-west-2.amazonaws.com/dmhr-data/deprivation-by-postcode.csv'
imd = pd.read_csv(url , index_col=False)

#rename the IMD
imd.rename(columns={'Postcode': 'postcode', 'Index of Multiple Deprivation Rank': 'imd_Rank', 'Index of Multiple Deprivation Decile': 'imd_decile'}, inplace=True)

#set the index to postcode
#output selected columns with imd Rand and Decile
imd1= imd.iloc[:, [0,4,5]].set_index('postcode')
imd1.head()
# Out:
#                            imd_Rank  imd_decile
# postcode
# TS18 1HU                       73.0         1.0
# TS18 2AW                      551.0         1.0
# TS26 8DB                      967.0         1.0
# TS1 3BE                      1914.0         1.0
# TS14 7DJ                     7082.0         3.0

# %%
#Use Sheff prac data 
shef_prac1.head()
# Out:
#       yearmonth prac_code                                  practice  \
# 900      201512    C81002  MOSS VALLEY MEDICAL PRACTICE
# 966      201512    C81070  OAKHILL MEDICAL PRACTICE
# 986      201512    C81095  DR HR MCMURRAY'S PRACTICE
# 1361     201512    C85004  PENISTONE GROUP PMS PRACTICE
# 1423     201512    C87004  KIVETON PARK MEDICAL PRACTICE
#
#                        address1                   address2  \
# 900   MOSS VALLEY MEDICAL PRACT  GOSBER ROAD  ECKINGTON
# 966   OAKHILL MEDICAL PRACTICE   OAKHILL ROAD  DRONFIELD
# 986   EMMETT CARR SURGERY        ABBEY PLACE  RENISHAW
# 1361  PENISTONE GROUP PRACTICE   THE SURGERY 19 HIGH ST
# 1423  KIVETON PARK PRIMARY CARE  CHAPEL WAY  KIVETON PARK
#
#                            city                     region  \
# 900   SHEFFIELD                  DERBYSHIRE
# 966   SHEFFIELD
# 986   NR.SHEFFIELD
# 1361  PENISTONE  SHEFFIELD       SOUTH YORKSHIRE
# 1423  SHEFFIELD                  SOUTH YORKSHIRE
#
#                        postcode
# 900   S21 4BZ
# 966   S18 2EJ
# 986   S21 3TY
# 1361  S36 6BR
# 1423  S26 6QU

# %%
#Reset index to postcode for merge 
shef_imd = shef_prac1.set_index('postcode')
shef_imd .head()
# Out:
#                            yearmonth prac_code  \
# postcode
# S21 4BZ                       201512    C81002
# S18 2EJ                       201512    C81070
# S21 3TY                       201512    C81095
# S36 6BR                       201512    C85004
# S26 6QU                       201512    C87004
#
#                                                            practice  \
# postcode
# S21 4BZ                    MOSS VALLEY MEDICAL PRACTICE
# S18 2EJ                    OAKHILL MEDICAL PRACTICE
# S21 3TY                    DR HR MCMURRAY'S PRACTICE
# S36 6BR                    PENISTONE GROUP PMS PRACTICE
# S26 6QU                    KIVETON PARK MEDICAL PRACTICE
#
#                                             address1  \
# postcode
# S21 4BZ                    MOSS VALLEY MEDICAL PRACT
# S18 2EJ                    OAKHILL MEDICAL PRACTICE
# S21 3TY                    EMMETT CARR SURGERY
# S36 6BR                    PENISTONE GROUP PRACTICE
# S26 6QU                    KIVETON PARK PRIMARY CARE
#
#                                             address2  \
# postcode
# S21 4BZ                    GOSBER ROAD  ECKINGTON
# S18 2EJ                    OAKHILL ROAD  DRONFIELD
# S21 3TY                    ABBEY PLACE  RENISHAW
# S36 6BR                    THE SURGERY 19 HIGH ST
# S26 6QU                    CHAPEL WAY  KIVETON PARK
#
#                                                 city  \
# postcode
# S21 4BZ                    SHEFFIELD
# S18 2EJ                    SHEFFIELD
# S21 3TY                    NR.SHEFFIELD
# S36 6BR                    PENISTONE  SHEFFIELD
# S26 6QU                    SHEFFIELD
#
#                                               region
# postcode
# S21 4BZ                    DERBYSHIRE
# S18 2EJ
# S21 3TY
# S36 6BR                    SOUTH YORKSHIRE
# S26 6QU                    SOUTH YORKSHIRE

# %%
shef_imd1 = shef_imd.iloc[:, [1,2,5]]
shef_imd1.head()
# Out:
#                           prac_code                                  practice  \
# postcode
# S21 4BZ                      C81002  MOSS VALLEY MEDICAL PRACTICE
# S18 2EJ                      C81070  OAKHILL MEDICAL PRACTICE
# S21 3TY                      C81095  DR HR MCMURRAY'S PRACTICE
# S36 6BR                      C85004  PENISTONE GROUP PMS PRACTICE
# S26 6QU                      C87004  KIVETON PARK MEDICAL PRACTICE
#
#                                                 city
# postcode
# S21 4BZ                    SHEFFIELD
# S18 2EJ                    SHEFFIELD
# S21 3TY                    NR.SHEFFIELD
# S36 6BR                    PENISTONE  SHEFFIELD
# S26 6QU                    SHEFFIELD

# %%
#merge on index 
shef_imd = pd.merge(shef_imd1,imd1, right_index=True, left_index=True)
shef_imd.head()
# Out:
#                           prac_code                                  practice  \
# postcode
# S1 3PB                       Y02565  SHEFFIELD CITY GP HC (WIC)
# S1 3PB                       Y02565  SHEFFIELD CITY GP HC (WIC)
# S1 3PB                       Y02566  SHEFFIELD CITY GP HC (REG)
# S1 3PB                       Y02566  SHEFFIELD CITY GP HC (REG)
# S1 4JP                       Y02025  DRUG AND ALCOHOL ACTION TEAM
#
#                                                 city  imd_Rank  imd_decile
# postcode
# S1 3PB                     SHEFFIELD                   11121.0         4.0
# S1 3PB                     SHEFFIELD                   11121.0         4.0
# S1 3PB                     SHEFFIELD                   11121.0         4.0
# S1 3PB                     SHEFFIELD                   11121.0         4.0
# S1 4JP                     SHEFFIELD                    2596.0         1.0

# %% [markdown]
# #### 3.Use the entire national dataset and identify the lowest relative spenders of statins from the first decile and the highest relative spenders of statins from the last decile. Now determine for all identified GP-practices for both groups (lowest and the highest) the associated Index of Multiple Deprivation (IMD). Use these two groups to assess whether the IMD-score differs. Use descriptive statistics for your answer.

# %%
# Use the entire national dataset and identify the lowest relative spenders of statins from the first decile and the highest relative spenders of statins from the last decile. 
practice_df.head()
# Out:
#    yearmonth prac_code                                  practice  \
# 0     201512    A81002  QUEENS PARK MEDICAL CENTRE
# 1     201512    A81003  VICTORIA MEDICAL PRACTICE
# 2     201512    A81004  WOODLANDS ROAD SURGERY
# 3     201512    A81005  SPRINGWOOD SURGERY
# 4     201512    A81006  TENNANT STREET MEDICAL PRACTICE
#
#                     address1                   address2  \
# 0  QUEENS PARK MEDICAL CTR    FARRER STREET
# 1  THE HEALTH CENTRE          VICTORIA ROAD
# 2  6 WOODLANDS ROAD
# 3  SPRINGWOOD SURGERY         RECTORY LANE
# 4  TENNANT ST MED PRACT       FARRER STREET
#
#                         city                     region  \
# 0  STOCKTON ON TEES           CLEVELAND
# 1  HARTLEPOOL                 CLEVELAND
# 2  MIDDLESBROUGH              CLEVELAND
# 3  GUISBOROUGH
# 4  STOCKTON ON TEES           CLEVELAND
#
#                     postcode
# 0  TS18 2AW
# 1  TS26 8DB
# 2  TS1 3BE
# 3  TS14 7DJ
# 4  TS18 2AT

# %%
imd1.head()
# Out:
#                            imd_Rank  imd_decile
# postcode
# TS18 1HU                       73.0         1.0
# TS18 2AW                      551.0         1.0
# TS26 8DB                      967.0         1.0
# TS1 3BE                      1914.0         1.0
# TS14 7DJ                     7082.0         3.0

# %%
#set postcode as index for both 
total_prac = practice_df.set_index('postcode')

#merge on index 
total_imd_merged = pd.merge(imd1, total_prac, right_index=True, left_index=True)

#set praccode to index 
total_prac1 = total_imd_merged.set_index('prac_code')

total_prac_statin = statin_pres.set_index('prac_code')

#merge on index 
total_imd_statin = pd.merge(total_prac1, total_prac_statin, right_index=True, left_index=True)
total_imd_statin.head()
# Out:
#            imd_Rank  imd_decile  yearmonth  \
# prac_code
# A81002        551.0         1.0     201512
# A81002        551.0         1.0     201512
# A81002        551.0         1.0     201512
# A81002        551.0         1.0     201512
# A81002        551.0         1.0     201512
#
#                                            practice  \
# prac_code
# A81002     QUEENS PARK MEDICAL CENTRE
# A81002     QUEENS PARK MEDICAL CENTRE
# A81002     QUEENS PARK MEDICAL CENTRE
# A81002     QUEENS PARK MEDICAL CENTRE
# A81002     QUEENS PARK MEDICAL CENTRE
#
#                             address1                   address2  \
# prac_code
# A81002     QUEENS PARK MEDICAL CTR    FARRER STREET
# A81002     QUEENS PARK MEDICAL CTR    FARRER STREET
# A81002     QUEENS PARK MEDICAL CTR    FARRER STREET
# A81002     QUEENS PARK MEDICAL CTR    FARRER STREET
# A81002     QUEENS PARK MEDICAL CTR    FARRER STREET
#
#                                 city                     region  sha  pct  \
# prac_code
# A81002     STOCKTON ON TEES           CLEVELAND                  Q45  00K
# A81002     STOCKTON ON TEES           CLEVELAND                  Q45  00K
# A81002     STOCKTON ON TEES           CLEVELAND                  Q45  00K
# A81002     STOCKTON ON TEES           CLEVELAND                  Q45  00K
# A81002     STOCKTON ON TEES           CLEVELAND                  Q45  00K
#
#                   bnf_code                                  bnf_name  items  \
# prac_code
# A81002     0212000AAAAAAAA  Rosuvastatin Calc_Tab 10mg                   32
# A81002     0212000AAAAABAB  Rosuvastatin Calc_Tab 20mg                   14
# A81002     0212000AAAAADAD  Rosuvastatin Calc_Tab 5mg                    22
# A81002     0212000ACAAABAB  Simvastatin/Ezetimibe_Tab 40mg/10mg           1
# A81002     0212000B0AAAAAA  Atorvastatin_Tab 10mg                       115
#
#               nic  act_cost  quantity  period
# prac_code
# A81002     793.32    733.96      1232  201512
# A81002     546.42    505.41       588  201512
# A81002     631.05    583.80       980  201512
# A81002      38.98     36.06        28  201512
# A81002     203.65    190.23      4874  201512

# %%
#sort the act cost in decreasing to identify lowest spenders 
total_imd_statin.sort_values('act_cost')
# Out:
#            imd_Rank  imd_decile  yearmonth  \
# prac_code
# Y04567      12585.0         4.0     201512
# Y04567      12585.0         4.0     201512
# Y01815      30354.0        10.0     201512
# Y00502      30064.0        10.0     201512
# Y00502      30064.0        10.0     201512
# Y05107        416.0         1.0     201512
# Y00502      30064.0        10.0     201512
# Y00502      30064.0        10.0     201512
# Y00502      30064.0        10.0     201512
# Y00502      30064.0        10.0     201512
# Y05107        416.0         1.0     201512
# Y05107        416.0         1.0     201512
# Y00502      30064.0        10.0     201512
# Y02764        596.0         1.0     201512
# Y01083       8580.0         3.0     201512
# Y00862      12354.0         4.0     201512
# Y00502      30064.0        10.0     201512
# Y05107        416.0         1.0     201512
# Y05107        416.0         1.0     201512
# Y01083       8580.0         3.0     201512
# Y00862      12354.0         4.0     201512
# Y01083       8580.0         3.0     201512
# Y00862      12354.0         4.0     201512
# Y05107        416.0         1.0     201512
# Y01083       8580.0         3.0     201512
# Y00502      30064.0        10.0     201512
# Y00502      30064.0        10.0     201512
# Y05107        416.0         1.0     201512
# Y02764        596.0         1.0     201512
# Y00502      30064.0        10.0     201512
# ...             ...         ...        ...
# L82052      23317.0         8.0     201512
# K83002      13830.0         5.0     201512
# K83002      13830.0         5.0     201512
# M89003      16957.0         6.0     201512
# G82037      28419.0         9.0     201512
# D82044      20633.0         7.0     201512
# C86007       1720.0         1.0     201512
# P85013       5118.0         2.0     201512
# P85013       5118.0         2.0     201512
# A81036      18432.0         6.0     201512
# G82097      23275.0         8.0     201512
# E83008      28661.0         9.0     201512
# E82082      29408.0         9.0     201512
# B81043      28287.0         9.0     201512
# C83040       9030.0         3.0     201512
# B81109       7612.0         3.0     201512
# L82052      23317.0         8.0     201512
# L83045      31235.0        10.0     201512
# J82007       8765.0         3.0     201512
# B85019       9218.0         3.0     201512
# M85063       5106.0         2.0     201512
# M85063       5106.0         2.0     201512
# B86010      32639.0        10.0     201512
# B81043      28287.0         9.0     201512
# M85063       5106.0         2.0     201512
# M85063       5106.0         2.0     201512
# M84031      19759.0         7.0     201512
# C83019       5695.0         2.0     201512
# B81109       7612.0         3.0     201512
# M84006      20488.0         7.0     201512
#
#                                            practice  \
# prac_code
# Y04567     LCH POLICE CUSTODY SUITES SERVICES
# Y04567     LCH POLICE CUSTODY SUITES SERVICES
# Y01815     PRIMECARE OOH
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y05107     STAR SCHEME
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y05107     STAR SCHEME
# Y05107     STAR SCHEME
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y02764     COMMUNITY RHEUMATOLOGY SERVICE
# Y01083     GO TO DOC OOH
# Y00862     CBS OOH
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y05107     STAR SCHEME
# Y05107     STAR SCHEME
# Y01083     GO TO DOC OOH
# Y00862     CBS OOH
# Y01083     GO TO DOC OOH
# Y00862     CBS OOH
# Y05107     STAR SCHEME
# Y01083     GO TO DOC OOH
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# Y05107     STAR SCHEME
# Y02764     COMMUNITY RHEUMATOLOGY SERVICE
# Y00502     IC24 LTD (NORFOLK & WISBECH OOH)
# ...                                             ...
# L82052     TRESCOBEAS SURGERY
# K83002     LAKESIDE HEALTHCARE
# K83002     LAKESIDE HEALTHCARE
# M89003     GPS HEALTHCARE
# G82037     HILDENBOROUGH MEDICAL GROUP
# D82044     VIDA HEALTHCARE
# C86007     DR P O'HORAN AND PARTNERS
# P85013     THE ROYTON & CROMPTON FAMILY PRACTICE
# P85013     THE ROYTON & CROMPTON FAMILY PRACTICE
# A81036     NORTON MEDICAL CENTRE
# G82097     JUBILEE MEDICAL CENTRE
# E83008     HEATHFIELDE MEDICAL CENTRE
# E82082     BIRCHWOOD SURGERY
# B81043     SOUTH AXHOLME PRACTICE
# C83040     ST. PETERS HILL SURGERY
# B81109     RIVERSIDE SURGERY
# L82052     TRESCOBEAS SURGERY
# L83045     BOVEY TRACEY & CHUDLEIGH PRACTICE
# J82007     THE ARNEWOOD PRACTICE MILTON MEDICAL CEN
# B85019     DOCTOR LANE HEALTH CENTRE
# M85063     MIDLANDS MEDICAL PARTNERSHIP
# C83019     3164.32   2930.09      4914  201512
# B81109     3191.42   2954.60      4956  201512
# M84006     3272.62   3030.82      5082  201512
#
# [162123 rows x 17 columns]

# %%
pat_demo = patient_demo2
#pat_demo.head()

relative_imd = pd.merge(total_imd_statin, total_statin, right_index=True, left_index=True)
#relative_imd.head()

relative_imd2 = relative_imd.iloc[:, [0,1,3,6,11,12,14,15,20,21]]
#relative_imd2.head()

rel_imd2 = relative_imd2.reset_index()
rel_imd2.rename(columns={'index': 'prac_code','act_cost_x':'act_cost'}, inplace=True)
#rel_imd2.head()

#cut the quintile into 10 
rel_imd2['decile'] = pd.qcut(rel_imd2['act_cost'], 10, labels=False)
lowest = rel_imd2[rel_imd2.decile == 0]
highest = rel_imd2[rel_imd2.decile == 9]

# %%
lowest_values = lowest.sort_values(by=['relative cost per patient'])
lowest_values.head()
# Out:
#       prac_code  imd_Rank  imd_decile  \
# 35439    C88627    8743.0         3.0
# 35440    C88627    8743.0         3.0
# 35442    C88627    8743.0         3.0
# 21326    B86110    8229.0         3.0
# 21325    B86110    8229.0         3.0
#
#                                        practice                       city  \
# 35439  UNIVERSITY HEALTH SERVICE HEALTH CENTRE   SHEFFIELD
# 35440  UNIVERSITY HEALTH SERVICE HEALTH CENTRE   SHEFFIELD
# 35442  UNIVERSITY HEALTH SERVICE HEALTH CENTRE   SHEFFIELD
# 21326  LEEDS STUDENT MEDICAL PRACTICE            BLENHEIM WALK
# 21325  LEEDS STUDENT MEDICAL PRACTICE            BLENHEIM WALK
#
#                                        bnf_name  items  act_cost  quantity_x  \
# 35439  Atorvastatin_Tab 20mg                         1      1.30          28
# 35440  Atorvastatin_Tab 40mg                         1      2.99          56
# 35442  Simvastatin_Tab 40mg                          1      2.07          56
# 21326  Pravastatin Sod_Tab 10mg                      1      2.14          56
# 21325  Atorvastatin_Tab 80mg                         1      5.17          56
#
#        Total_All  relative cost per patient  decile
# 35439      29880                   0.000420       0
# 35440      29880                   0.000420       0
# 35442      29880                   0.000420       0
# 21326      39138                   0.000517       0
# 21325      39138                   0.000517       0

# %%
highest_values = highest.sort_values(by=['relative cost per patient'])
highest_values.head()
# Out:
#        prac_code  imd_Rank  imd_decile  \
# 127458    N82117   10339.0         4.0
# 80745     H85001   15132.0         5.0
# 72448     G85002   17096.0         6.0
# 72436     G85002   17096.0         6.0
# 72424     G85002   17096.0         6.0
#
#                                         practice                       city  \
# 127458  BROWNLOW GROUP PRACTICE                   LIVERPOOL
# 80745   WANDSWORTH MEDICAL CENTRE                 WANDSWORTH
# 72448   STREATHAM HIGH PRACTICE                   STREATHAM
# 72436   STREATHAM HIGH PRACTICE                   STREATHAM
# 72424   STREATHAM HIGH PRACTICE                   STREATHAM
#
#                                         bnf_name  items  act_cost  quantity_x  \
# 127458  Rosuvastatin Calc_Tab 10mg                   19    300.73         504
# 80745   Rosuvastatin Calc_Tab 20mg                   12    409.57         476
# 72448   Atorvastatin_Tab 40mg                       197    320.99        5789
# 72436   Atorvastatin_Tab 40mg                       197    320.99        5789
# 72424   Atorvastatin_Tab 40mg                       197    320.99        5789
#
#         Total_All  relative cost per patient  decile
# 127458      35236                   0.049433       9
# 80745       16292                   0.056035       9
# 72448       14468                   0.058167       9
# 72436       14468                   0.058167       9
# 72424       14468                   0.058167       9

# %% [markdown]
# #### Now determine for all identified GP-practices for both groups (lowest and the highest) the associated Index of Multiple Deprivation (IMD)

# %%
lowest_values['imd_Rank'].max()
# Out:
# 32841.0

# %%
lowest_values['imd_Rank'].min()
# Out:
# 15.0

# %%
highest_values['imd_Rank'].max()
# Out:
# 32841.0

# %%
highest_values['imd_Rank'].min()
# Out:
# 3.0

# %% [markdown]
# #### Use these two groups to assess whether the IMD-score differs. Use descriptive statistics for your answer.

# %%
highest_values['imd_Rank'].plot(kind='box', by='group')

# %%
lowest_values['imd_Rank'].plot(kind='box', by='group')

# %% [markdown]
# #### 4.Identify for all GP-practices the associated nine English regions. Identify for each region the associated 75 mortality rate for cardiovascular diseases for the year 2015.

# %%
url = 'https://s3.eu-west-2.amazonaws.com/dmhr-data/NHSOF_1.1_I00656_D.csv'
mortality_data = pd.read_csv(url , index_col=False)
mortality_data.head()

#Identify Year == 2015

mortality_15 = mortality_data[mortality_data['Year'].astype(str).str[-4:].str.contains('2015')]
mortality_15
# Out:
#      Year      Period of coverage           Breakdown    Level  \
# 1    2015  1/1/2015 to 31/12/2015             England  England
# 30   2015  1/1/2015 to 31/12/2015             England  England
# 31   2015  1/1/2015 to 31/12/2015             England  England
# 32   2015  1/1/2015 to 31/12/2015             England  England
# 33   2015  1/1/2015 to 31/12/2015             England  England
# 34   2015  1/1/2015 to 31/12/2015             England  England
# 35   2015  1/1/2015 to 31/12/2015             England  England
# 36   2015  1/1/2015 to 31/12/2015             England  England
# 37   2015  1/1/2015 to 31/12/2015             England  England
# 38   2015  1/1/2015 to 31/12/2015             England  England
# 39   2015  1/1/2015 to 31/12/2015             England  England
# 40   2015  1/1/2015 to 31/12/2015             England  England
# 41   2015  1/1/2015 to 31/12/2015             England  England
# 42   2015  1/1/2015 to 31/12/2015             England  England
# 43   2015  1/1/2015 to 31/12/2015             England  England
# 44   2015  1/1/2015 to 31/12/2015             England  England
# 45   2015  1/1/2015 to 31/12/2015             England  England
# 254  2015  1/1/2015 to 31/12/2015             England  England
# 255  2015  1/1/2015 to 31/12/2015             England  England
# 256  2015  1/1/2015 to 31/12/2015             England  England
# 257  2015  1/1/2015 to 31/12/2015             England  England
# 258  2015  1/1/2015 to 31/12/2015             England  England
# 259  2015  1/1/2015 to 31/12/2015             England  England
# 260  2015  1/1/2015 to 31/12/2015             England  England
# 261  2015  1/1/2015 to 31/12/2015             England  England
# 262  2015  1/1/2015 to 31/12/2015             England  England
# 263  2015  1/1/2015 to 31/12/2015             England  England
# 264  2015  1/1/2015 to 31/12/2015             England  England
# 265  2015  1/1/2015 to 31/12/2015             England  England
# 266  2015  1/1/2015 to 31/12/2015             England  England
# ..    ...                     ...                 ...      ...
# 840  2015  1/1/2015 to 31/12/2015  Deprivation decile        1
# 257              England    Male  10 to 14             0.7      0.3      1.2
# 258              England    Male  15 to 19             1.7      1.1      2.5
# 259              England    Male  20 to 24             3.1      2.3        4
# 260              England    Male  25 to 29             4.6      3.7      5.7
# 261              England    Male  30 to 34             7.7      6.5      9.1
# 262              England    Male  35 to 39            14.6     12.9     16.5
# 263              England    Male  40 to 44            32.6       30     35.3
# 264              England    Male  45 to 49            60.7     57.3     64.3
# 265              England    Male  50 to 54           101.3     96.8    105.9
# 266              England    Male  55 to 59           158.3    152.2    164.5
# ..                   ...     ...       ...             ...      ...      ...
# 840    1 - Most deprived  Person       All           146.1    142.1    150.2
# 841                    2  Person       All           117.2    113.7    120.8
# 842                    3  Person       All           102.2       99    105.4
# 843                    4  Person       All            84.1     81.3     86.9
# 844                    5  Person       All            71.7     69.3     74.2
# 845                    6  Person       All            64.9     62.6     67.2
# 846                    7  Person       All            57.5     55.4     59.6
# 847                    8  Person       All            52.2     50.2     54.2
# 848                    9  Person       All            46.4     44.5     48.3
# 849  10 - Least deprived  Person       All            40.1     38.4     41.9
# 910    1 - Most deprived  Female       All              94     89.5     98.7
# 911                    2  Female       All            74.5     70.6     78.6
# 912                    3  Female       All            65.8     62.3     69.5
# 913                    4  Female       All            52.1     49.2     55.3
# 914                    5  Female       All            45.3     42.7     48.1
# 915                    6  Female       All            41.8     39.3     44.4
# 916                    7  Female       All            35.1     32.9     37.5
# 917                    8  Female       All            32.2     30.1     34.5
# 918                    9  Female       All            28.2     26.3     30.3
# 919  10 - Least deprived  Female       All            24.7     22.9     26.7
# 980    1 - Most deprived    Male       All           199.5    192.8    206.3
# 981                    2    Male       All           162.4    156.5    168.6
# 982                    3    Male       All           140.4    135.1    145.8
# 983                    4    Male       All           117.6      113    122.3
# 984                    5    Male       All            99.6     95.5    103.8
# 985                    6    Male       All            89.3     85.5     93.2
# 986                    7    Male       All            81.2     77.6     84.8
# 987                    8    Male       All            73.4       70     76.9
# 988                    9    Male       All            65.7     62.6       69
# 989  10 - Least deprived    Male       All            56.6     53.6     59.6
#
#     Numerator Denominator
# 1      33,664  50,360,500
# 30     10,835  25,186,400
# 31         28   1,674,300
# 32          7   1,638,600
# 33          4   1,465,100
# 34         12   1,562,800
# 35         29   1,759,800
# 36         42   1,870,600
# 37         87   1,870,100
# 38        130   1,740,300
# 39        255   1,831,300
# 40        462   1,967,600
# 41        696   1,927,600
# 42        964   1,656,700
# 43      1,504   1,482,000
# 44      2,634   1,552,400
# 45      3,981   1,187,400
# 254    22,829  25,174,100
# 255        24   1,760,400
# 256         4   1,718,900
# 257        10   1,535,200
# 258        28   1,650,500
# 259        56   1,832,500
# 260        87   1,887,400
# 261       143   1,857,900
# 262       253   1,730,600
# 263       588   1,805,100
# 264     1,167   1,921,800
# 265     1,907   1,883,400
# 266     2,567   1,621,700
# ..        ...         ...
# 840     5,181   5,169,300
# 841     4,294   5,270,700
# 842     4,031   5,279,100
# 843     3,618   5,188,800
# 844     3,350   5,044,900
# 845     3,186   5,012,300
# 846     2,902   4,919,100
# 847     2,655   4,895,800
# 848     2,388   4,856,600
# 849     2,059   4,723,900
# 910     1,677   2,582,300
# 911     1,390   2,636,000
# 912     1,318   2,623,300
# 913     1,144   2,579,400
# 914     1,083   2,517,100
# 915     1,056   2,504,900
# 916       911   2,464,000
# 917       846   2,455,100
# 918       752   2,440,000
# 919       658   2,384,400
# 980     3,504   2,587,100
# 981     2,904   2,634,700
# 982     2,713   2,655,800
# 983     2,474   2,609,400
# 984     2,267   2,527,700
# 985     2,130   2,507,500
# 986     1,991   2,455,100
# 987     1,809   2,440,700
# 988     1,636   2,416,700
# 989     1,401   2,339,500
#
# [90 rows x 12 columns]

# %%
#Sort Data by Region 
mortality_15['Breakdown'].value_counts()
# Out:
# Region    90
# Name: Breakdown, dtype: int64

# %%
#Data on the Regions are split accross the tables 

reg_data = mortality_15.loc[(mortality_15['Breakdown'] == 'Region')]
reg_data = reg_data[['Year', 'Level description', 'Indicator value']]
#reg_data

# %%
# Sort Data by Region 
# print values from the Breakdown column the are Regions 

(mortality_15['Breakdown'] == 'Region')
sort_mortality = mortality_15.loc[mortality_15['Breakdown']== 'Region']

# %%
mortality = sort_mortality.groupby('Level description')['Level description', 'Indicator value'].sum()
mortality.head()
# Out:
#                                                      Level description  \
# Level description
# 1 - Most deprived    1 - Most deprived1 - Most deprived1 - Most dep...
# 10 - Least deprived  10 - Least deprived10 - Least deprived10 - Lea...
# 2                                                                  222
# 3                                                                  333
# 4                                                                  444
#
#                     Indicator value
# Level description
# 1 - Most deprived      146.194199.5
# 10 - Least deprived    40.124.756.6
# 2                    117.274.5162.4
# 3                    102.265.8140.4
# 4                     84.152.1117.6

# %% [markdown]
# #### 5.Visualize (using matplotlib) for each region spending for statins [x-axis] and the mortality rate [y-axis]. Assess whether relative spending for statin prescriptions in each regions correlates with the mortality rate from cardiovascular diseases.

# %%
#import postcode data
url = 'https://s3.eu-west-2.amazonaws.com/dmhr-data/postcodes.csv'
ons_postcodes = pd.read_csv(url , index_col=False)
ons_postcodes .head()
# Out:
#   Postcode 1 Postcode 2 Postcode 3 Date Introduced  User Type   Easting  \
# 0    S20 6RU   S20  6RU    S20 6RU         06-1997          0  441432.0
# 1    TW4 7BD   TW4  7BD    TW4 7BD         01-1980          0  512373.0
# 2    GU513ZQ   GU51 3ZQ   GU51 3ZQ         05-2003          1  481569.0
# 3    OX4 6BE   OX4  6BE    OX4 6BE         06-2000          0  455440.0
# 4    TA7 9JH   TA7  9JH    TA7 9JH         01-1980          0  338745.0
#
#    Northing  Positional Quality County Code                  County Name  \
# 0  382852.0                   1   E99999999  (pseudo) England (UA/MD/LB)
# 1  175453.0                   1   E99999999  (pseudo) England (UA/MD/LB)
# 2  155037.0                   1   E10000014                    Hampshire
# 3  203036.0                   1   E10000025                  Oxfordshire
# 4  139337.0                   1   E10000027                     Somerset
#
#      ...     Middle Super Output Area Code Middle Super Output Area Name  \
# 0    ...                         E02001671                           NaN
# 1    ...                         E02000541                           NaN
# 2    ...                         E02004757                           NaN
# 3    ...                         E02005956                           NaN
# 4    ...                         E02006072                           NaN
#
#   Output Area Classification Code  \
# 0                             6B3
# 1                             4B1
# 2                             6B4
# 3                             4A1
# 4                             1A2
#
#                      Output Area Classification Name Longitude   Latitude  \
# 0  Suburbanites;Semi-detached suburbia;Semi-detac... -1.379193  53.340953
# 1  Multicultural metropolitans;Challenged Asian t... -0.383652  51.466899
# 2  Suburbanites;Semi-detached suburbia;Older work... -0.831674  51.288637
# 3  Multicultural metropolitans;Rented family livi... -1.198788  51.723313
# 4  Rural residents;Farming communities;Establishe... -2.877144  51.149999
#
#   Spatial Accuracy Last Uploaded                Location Socrata ID
# 0   Postcode Level    21/09/2017  (53.340953, -1.379193)    1311804
# 1   Postcode Level    21/09/2017  (51.466899, -0.383652)    1630253
# 2   Postcode Level    21/09/2017  (51.288637, -0.831674)     652126
# 3   Postcode Level    21/09/2017  (51.723313, -1.198788)    1158807
# 4   Postcode Level    21/09/2017  (51.149999, -2.877144)    1547901
#
# [5 rows x 36 columns]

# %%
ons_postcodes['Country Name'].value_counts(dropna=False)
# Out:
# England             1447953
# Scotland             156913
# Wales                 91075
# Northern Ireland      47923
# Channel Islands        6582
# Isle of Man            4699
# NaN                    1044
# Name: Country Name, dtype: int64

# %%
ons_postcodes['Region Name'].value_counts()
# Out:
# South East                  252297
# North West                  194243
# London                      181151
# South West                  175687
# East of England             164339
# Yorkshire and The Humber    148294
# West Midlands               142611
# East Midlands               114829
# North East                   74502
# Name: Region Name, dtype: int64

# %%
#each region statin spend 
#ons_postcode_region = ons_postcodes['Region Name','Postcode 1']
#ons_postcode_region.head()

ons_postcode_region1 = ons_postcodes.iloc[:,[0,17]]
#ons_postcode_region1 = ons_postcode_region1.groupby('Region Name')
ons_postcode_region1.head()
#Remove NAN#
# Out:
#   Postcode 1               Region Name
# 0    S20 6RU  Yorkshire and The Humber
# 1    TW4 7BD                    London
# 2    GU513ZQ                South East
# 3    OX4 6BE                South East
# 4    TA7 9JH                South West

# %%
#visualise each statin spending 
#ons_all = ons_postcode_region1.set_index('Postcode 1')
#ons_all.head()

# %%
total_imd_statin1 = total_imd_statin.reset_index

# %%
total_imd_statin1.head()
# Out:
#   prac_code  imd_Rank  imd_decile  yearmonth  \
# 0    A81002     551.0         1.0     201512
# 1    A81002     551.0         1.0     201512
# 2    A81002     551.0         1.0     201512
# 3    A81002     551.0         1.0     201512
# 4    A81002     551.0         1.0     201512
#
#                                    practice                   address1  \
# 0  QUEENS PARK MEDICAL CENTRE                QUEENS PARK MEDICAL CTR
# 1  QUEENS PARK MEDICAL CENTRE                QUEENS PARK MEDICAL CTR
# 2  QUEENS PARK MEDICAL CENTRE                QUEENS PARK MEDICAL CTR
# 3  QUEENS PARK MEDICAL CENTRE                QUEENS PARK MEDICAL CTR
# 4  QUEENS PARK MEDICAL CENTRE                QUEENS PARK MEDICAL CTR
#
#                     address2                       city  \
# 0  FARRER STREET              STOCKTON ON TEES
# 1  FARRER STREET              STOCKTON ON TEES
# 2  FARRER STREET              STOCKTON ON TEES
# 3  FARRER STREET              STOCKTON ON TEES
# 4  FARRER STREET              STOCKTON ON TEES
#
#                       region  sha  pct         bnf_code  \
# 0  CLEVELAND                  Q45  00K  0212000AAAAAAAA
# 1  CLEVELAND                  Q45  00K  0212000AAAAABAB
# 2  CLEVELAND                  Q45  00K  0212000AAAAADAD
# 3  CLEVELAND                  Q45  00K  0212000ACAAABAB
# 4  CLEVELAND                  Q45  00K  0212000B0AAAAAA
#
#                                    bnf_name  items     nic  act_cost  \
# 0  Rosuvastatin Calc_Tab 10mg                   32  793.32    733.96
# 1  Rosuvastatin Calc_Tab 20mg                   14  546.42    505.41
# 2  Rosuvastatin Calc_Tab 5mg                    22  631.05    583.80
# 3  Simvastatin/Ezetimibe_Tab 40mg/10mg           1   38.98     36.06
# 4  Atorvastatin_Tab 10mg                       115  203.65    190.23
#
#    quantity  period
# 0      1232  201512
# 1       588  201512
# 2       980  201512
# 3        28  201512
# 4      4874  201512

# %% [markdown]
# # ASSIGNMENT D
# Using the Google FluTrends surveillance data, pick two random countries, one in the Northern hemisphere and one in the Southern hemisphere. For each of country:

# %% [markdown]
# ### 1.
# Provide a visualisation of the seasonal patterns across all years.

# %%
import pandas as pd 
#AUSTRIA
#Loading the Data Sets from Austria Google FLu Trends 
austria ='https://www.google.org/flutrends/about/data/flu/at/data.txt'
cols2 = ['Date','Austria','Carinthia','Lower Austria','Upper Austria','Salzburg','Styria','Tyrol','Vorarlberg','Vienna']
austria =pd.read_csv(austria, sep=',', header=8).rename(columns=lambda x: x.strip())#To remove text 
austria['Date'] = pd.to_datetime(austria['Date'])
austria.head()
# Out:
#         Date  Austria  Carinthia  Lower Austria  Upper Austria  Salzburg  \
# 0 2003-09-28      515        NaN            NaN            463       NaN
# 1 2003-10-05      752        NaN            NaN            482       NaN
# 2 2003-10-12      720        NaN            NaN            551       NaN
# 3 2003-10-19      727        NaN          425.0            573       NaN
# 4 2003-10-26      710        NaN          462.0            626       NaN
#
#    Styria  Tyrol  Vorarlberg  Vienna
# 0     NaN    NaN         NaN     582
# 1     NaN    NaN         NaN     789
# 2     NaN    NaN         NaN     785
# 3     NaN    NaN         NaN     720
# 4     NaN    NaN         NaN     646

# %%
#set the index for the data
#austria.set_index('Date', inplace=True)
#austria.head()

# %%
#SOUTH_AFRICA
#Loading the Data Sets from South Google FLu Trends
south_africa ='https://www.google.org/flutrends/about/data/flu/za/data.txt'
#cols2 = ['Date', 'SouthAfrica', 'Gauteng', 'Kwazulu-Natal', 'Western Cape']
s_africa =pd.read_csv(south_africa, sep=',', header=8).rename(columns=lambda x: x.strip()) #To remove text 
s_africa['Date'] = pd.to_datetime(s_africa['Date'])
s_africa.head()
# Out:
#         Date  South Africa  Gauteng  Kwazulu-Natal  Western Cape
# 0 2006-01-15          1835      NaN            NaN           NaN
# 1 2006-01-22          1866   2216.0            NaN           NaN
# 2 2006-01-29          1991   2081.0            NaN        1733.0
# 3 2006-02-05          2169   2136.0            NaN        1977.0
# 4 2006-02-12          1958   2047.0            NaN        2038.0

# %%
s_africa.rename(columns={'South Africa': 'SouthAfrica'}, inplace=True)

# %%
#s_africa.set_index('Date', inplace=True)
#s_africa.head()

# %%
#Total Austrian FLuTrends 
ax = austria.plot(legend ='left', x='Date', y = 'Austria', figsize=(15, 6), title = 'Flu Trend in Austria' ,grid=True)

# %%
ax = s_africa.plot(legend ='left', x='Date', y = 'SouthAfrica', color = 'purple', title = 'Flu Trend in South Africa',figsize=(15, 6), grid=True)

# %% [markdown]
# ### 2.
# Calculate the yearly minimum and maximum for each country.

# %%
#Yearly Maximum and Yearly Minimum South Africa 
s_africa['Year'] = s_africa.Date.dt.to_period('Y')

# %%
s_africa_max = s_africa.groupby('Year')['SouthAfrica'].max()
s_africa_max
# Out:
# Year
# 2006    4707
# 2007    4253
# 2008    4149
# 2009    6514
# 2010    3969
# 2011    4060
# 2012    4232
# 2013    4204
# 2014    4634
# 2015    4964
# Freq: A-DEC, Name: SouthAfrica, dtype: int64

# %%
s_africa_max.mean()
# Out:
# 4568.6

# %%
s_africa_min = s_africa.groupby('Year')['SouthAfrica'].min()
s_africa_min
# Out:
# Year
# 2006    1626
# 2007    1662
# 2008    1630
# 2009    1475
# 2010    1628
# 2011    1622
# 2012    1572
# 2013    1758
# 2014    1846
# 2015    2067
# Freq: A-DEC, Name: SouthAfrica, dtype: int64

# %%
s_africa_min.mean()
# Out:
# 1688.6

# %%
#Yearly Maximum and Yearly Minimum Austria 
austria['Year'] = austria.Date.dt.to_period('Y')

# %%
austria_max = austria.groupby('Year')['Austria'].max()
austria_max
# Out:
# Year
# 2003     898
# 2004    1016
# 2005    2396
# 2006    1054
# 2007    1607
# 2008    1750
# 2009    2602
# 2010     867
# 2011    1635
# 2012    1540
# 2013    2408
# 2014    1602
# 2015    2972
# Freq: A-DEC, Name: Austria, dtype: int64

# %%
austria_max.mean()
# Out:
# 1719.0

# %%
austria_min = austria.groupby('Year')['Austria'].min()
austria_min
# Out:
# Year
# 2003    515
# 2004    408
# 2005    414
# 2006    374
# 2007    431
# 2008    390
# 2009    466
# 2010    389
# 2011    291
# 2012    409
# 2013    433
# 2014    491
# 2015    494
# Freq: A-DEC, Name: Austria, dtype: int64

# %%
austria_min.mean()
# Out:
# 423.46153846153845

# %% [markdown]
# ### 2a.
# Provide and plot a reasonable mathematical function that could be used as an approximation for the seasonal trend for each country.

# %%
from statistics import mean
import numpy as np

xs = s_africa(['Date'], dtype=np.float64)
ys = s_africa(['SouthAfrica'], dtype=np.float64)

def best_fit_slope(xs,ys):
    m = (((mean(xs)*mean(ys)) - mean(xs*ys)) /
         ((mean(xs)*mean(xs)) - mean(xs*xs)))
    return m

m = best_fit_slope(xs,ys)
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-5f365e553bdd> in <module>()
#       2 import numpy as np
#       3
# ----> 4 xs = s_africa(['Date'], dtype=np.float64)
#       5 ys = s_africa(['SouthAfrica'], dtype=np.float64)
#       6
#
# TypeError: 'DataFrame' object is not callable
